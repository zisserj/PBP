# %%
from problog.program import PrologString
from problog import get_evaluatable

# %%
model ='''

%%%%%%%%%%
% model
% - start(modelID,state) complete AD
% - trans(modelID,time,fromState,toState) possibly incomplete AD per fromState
% - emit(modelID,time,state,symbol) possibly incomplete AD per state
%%%%%%%%%%
% example 1: weather (with umbrella yes/no added)

# %init
start(bt1,s0).
start(bt21,s0).
start(bt22,s0).
start(bt23,s0).
start(bt31,s0).
start(bt32,s0).
start(bt33,s0).

# %bt1
trans(bt1,s0,h1,s1).
trans(bt1,s0,h2,s1).
trans(bt1,s0,h3,s1).

trans(bt1,s1,g1,s2).
trans(bt1,s1,g2,s2).
trans(bt1,s1,g3,s2).

trans(bt1,s2,o1,s31).
trans(bt1,s2,o2,s32).
trans(bt1,s2,o3,s33).

1/3::request(bt1,s0,h1);
1/3::request(bt1,s0,h2);
1/3::request(bt1,s0,h3).

1/3::request(bt1,s1,g1);
1/3::request(bt1,s1,g2);
1/3::request(bt1,s1,g3).

request(bt1,s2,o1).
request(bt1,s2,o2).
request(bt1,s2,o3).


trans(bt21,s0,h1,s1). 
block(bt21,s1,o1).
trans(bt21,s0,H,s0):- not(H == h1).
trans(bt21,s1,_,s1).

trans(bt22,s0,h2,s1). 
block(bt22,s1,o2).
trans(bt22,s0,H,s0):- not(H == h2).
trans(bt22,s1,_,s1).

trans(bt23,s0,h3,s1). 
block(bt23,s1,o3).
trans(bt23,s0,H,s0):- not(H == h3).
trans(bt23,s1,_,s1).

trans(bt31,s0,g1,s1). 
block(bt31,s1,o1).
trans(bt31,s0,H,s0):- not(H == g1).
trans(bt31,s1,_,s1).

trans(bt32,s0,g2,s1). 
block(bt32,s1,o2).
trans(bt32,s0,H,s0):- not(H == g2).
trans(bt32,s1,_,s1).


trans(bt33,s0,g3,s1). 
block(bt33,s1,o3).
trans(bt33,s0,H,s0):- not(H == g3).
trans(bt33,s1,_,s1). 

%%%%%%%%%
% background: which state are we in at which time?
% state(modelID,time,state)
%%%%%%%%%
state(0,S1,S21,S22,S23,S31,S32,S33) :- start(bt1,S1),
                                       start(bt21,S21),
                                       start(bt22,S22),
                                       start(bt23,S23),
                                       start(bt31,S31),
                                       start(bt32,S32),
                                       start(bt33,S33).
                                       
                                       

state(T,S1,S21,S22,S23,S31,S32,S33) :- T > 0, TT is T-1, 
                    state(TT,SS1,SS21,SS22,SS23,SS31,SS32,SS33),
                    trans(bt1,SS1,E,S1),
                    trans(bt21,SS21,E,S21),
                    trans(bt22,SS22,E,S22),
                    trans(bt23,SS23,E,S23),
                    trans(bt31,SS31,E,S31),
                    trans(bt32,SS32,E,S32),
                    trans(bt33,SS33,E,S33),
                    requested(SS1,SS21,SS22,SS23,SS31,SS32,SS33,E),
                    not(blocked(SS1,SS21,SS22,SS23,SS31,SS32,SS33,E)).


requested(S1,S21,S22,S23,S31,S32,S33,E) :-      
                    request(bt1,S1,E);
                    request(bt21,S21,E);
                    request(bt22,S22,E);
                    request(bt23,S23,E);
                    request(bt31,S31,E);
                    request(bt32,S32,E);
                    request(bt33,S33,E).
                    
                    
blocked(S1,S21,S22,S23,S31,S32,S33,E) :-      
                    block(bt1,S1,E);
                    block(bt21,S21,E);
                    block(bt22,S22,E);
                    block(bt23,S23,E);
                    block(bt31,S31,E);
                    block(bt32,S32,E);
                    block(bt33,S33,E).                    

obs_h1:- state(1,_,s1,_,_,_,_,_).
obs_h2:- state(1,_,_,s1,_,_,_,_).
obs_h3:- state(1,_,_,_,s1,_,_,_).
obs_g2:- state(2,_,_,_,_,_,s1,_).
obs_o1:- state(3,s31,_,_,_,_,_,_).
evidence(obs_o1).
evidence(obs_g2).
# %query(state(1,s1,s0,s1,s0,s0,s0,s0)).
# %query(state(1,_,_,_,_,_,_,_)).
query(obs_h1).
query(obs_h2).
query(obs_h3).
% query(observe_sequence(weather,L)) :- between(0,2,N),length(L,N).
% query(state_sequence(weather,L)) :- between(0,2,N),length(L,N).
% query(state(weather,T,_)) :- between(0,2,T).
% query(observe(weather,T,_)) :- between(0,2,T).
'''

# %%
result = get_evaluatable().create_from(PrologString(model)).evaluate()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/ddnnf_formula.py in _compile_with_dsharp(cnf, nnf, smooth, **kwdargs)
#     298         try:
# --> 299             result = _compile(cnf, cmd, cnf_file, nnf_file)
#     300         except subprocess.CalledProcessError:
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/ddnnf_formula.py in _compile(cnf, cmd, cnf_file, nnf_file)
#     351                 if attempts_left == 0:
# --> 352                     raise err
#     353         return _load_nnf(nnf_file, cnf)
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/ddnnf_formula.py in _compile(cnf, cmd, cnf_file, nnf_file)
#     346                 with open(os.devnull, "w") as OUT_NULL:
# --> 347                     subprocess_check_call(cmd, stdout=OUT_NULL)
#     348                 success = True
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/util.py in subprocess_check_call(*popenargs, **kwargs)
#     190             cmd = popenargs[0]
# --> 191         raise subprocess.CalledProcessError(retcode, cmd)
#     192     return 0
#
# CalledProcessError: Command '['dsharp', '-Fnnf', '/var/folders/5w/bn3cqnws0hdc4ppfjbrr95gm0000gp/T/tmp_9ixs_x_.nnf', '-smoothNNF', '-disableAllLits', '/var/folders/5w/bn3cqnws0hdc4ppfjbrr95gm0000gp/T/tmp3iaxappg.cnf']' died with <Signals.SIGSEGV: 11>.
#
# During handling of the above exception, another exception occurred:
#
# DSharpError                               Traceback (most recent call last)
# <ipython-input-10-9bb55b847561> in <module>
# ----> 1 result = get_evaluatable().create_from(PrologString(model)).evaluate()
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/core.py in create_from(cls, obj, **kwdargs)
#     156         :return: object of current class
#     157         """
# --> 158         return ProbLog.convert(obj, cls, **kwdargs)
#     159
#     160     # noinspection PyPep8Naming
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/core.py in convert(cls, src, target, **kwdargs)
#     121                 while path:
#     122                     if path[1] is not None:
# --> 123                         next_obj = path[0](current_obj, path[1](**kwdargs), **kwdargs)
#     124                     else:
#     125                         next_obj = path[1].create_from_default_action(
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/problog/ddnnf_formula.py in _compile_with_dsharp(cnf, nnf, smooth, **kwdargs)
#     299             result = _compile(cnf, cmd, cnf_file, nnf_file)
#     300         except subprocess.CalledProcessError:
# --> 301             raise DSharpError()
#     302
#     303         try:
#
# DSharpError: DSharp has encountered an error. This is a known issue. See KNOWN_ISSUES for details on how to resolve this problem.

# %%
model = """0.3::a.  query(a)."""
result = get_evaluatable().create_from(PrologString(model)).evaluate()
result
# Out:
# {a: 0.3}
